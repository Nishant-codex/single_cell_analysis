# %% [markdown]
# # Supplementary Figure: Clustered Membrane Potential Traces
#
# This notebook visualizes representative membrane potential traces for six clusters, comparing Fast Neuron (FN) and Current Clamp (CC) recordings. Each cluster section includes:
#
# - **FN trace**: Extracted from `.mat` files, plotted over a specified time window.
# - **CC trace**: Extracted from corresponding `.mat` files, plotted for comparison.
#
# Custom color palettes are defined for cluster visualization. Figures are saved for publication use.

# %%
#@title imports 
import os

import pandas as pd
import sys
sys.path.append('C:/Users/Nishant Joshi/Downloads/Old_code/repo/single_cell_analysis/scripts')
sys.path.append(os.getcwd()+'/../scripts/')
sys.path.append('C:/Users/Nishant Joshi/Model_fitting/GIFFittingToolbox/src/examples/')
from CC_analysis_utils import *
import matplotlib.pyplot as plt
from utils import *
import numpy as np
import seaborn as sns

# %%
pal = ["#00202e","#003f5c","#2c4875","#8a508f","#bc5090","#ff6361","#ff8531","#ffa600","#ffd380",[0.969,	0.349, 0.549]]
CUSTOM_PAL_SORT_3 = ['#5e60ce','#00c49a','#ffca3a','#D81159','#fe7f2d','#7bdff2','#0496ff','#efa6c9','#ced4da']
GMM_PAL = ['#d62424','#12db41','#f0c905','#248cd6']

# In RGB form
coherence_colors = [[0.609, 0.283, 0.724],
                    [0.259,	0.314, 0.635],
                    [0.02,	0.9, 0.3],
                    [0.898,	0.654, 0.169],
                    [0.821, 0.012, 0.198],
                    [0.298,	0.654, 0.169],
                    [0.898,	0.41 , 0.165],  
                    [0.834,	0.3 , 0.265],
                    [0.912,	0.8 , 0.112],
                    [0.812,	0.3 , 0.734],
                    [0.109, 0.483, 0.324],
                    [0.159,	0.914, 0.635],
                    [0.251,	0.512, 0.198],
                    [0.676,	0.631, 0.859],
                    [0.969,	0.349, 0.549],]
sns.palplot(CUSTOM_PAL_SORT_3)
sns.palplot(GMM_PAL)
sns.palplot(coherence_colors)

# %%
df = pd.read_pickle("G:/My Drive/Data For Publication/Data_feature_set/combined_FN_acsf.pkl")
df[df.waveform_labels_FN==1.0].exp_name
# Out:
# 1         170616_NC_20
# 4         170627_NC_30
# 18        170717_NC_65
# 19        170718_NC_67
# 21        170718_NC_69
# 29        170725_NC_82
# 30        170726_NC_83
# 32        170726_NC_87
# 33        170727_NC_88
# 37        170801_NC_93
# 42       170814_NC_100
# 54       170830_NC_116
# 57       170914_NC_123
# 59       171010_NC_126
# 61       171010_NC_128
# 73       171110_NC_143
# 75       171110_NC_145
# 94        asli_2819_E3
# 101      asli_25719_E3
# 106      asli_31719_E3
# 113       asli_5819_E4
# 115       asli_6819_E1
# 118       asli_6819_E4
# 126        NC_30817_E1
# 127        NC_14917_E1
# 147      xuan_20919_E1
# 154      xuan_26619_E6
# 166    payam_101019_E4
# 173     payam_25919_E1
# 185       xuan_9519_E3
# 188       xuan_9919_E3
# Name: exp_name, dtype: object

# %% [markdown]
# ### Cluster 1

# %%
data_path = "D:/Niccolo_Files_FN_CC/FN_analyzed/170615_NC_19_FN_analyzed.mat"
data = loadmatInPy(data_path)

t = np.arange(0,5,1/20000)

plt.plot(t,data[0]['membrane_potential'][:5*20000],c='black')
# plt.plot(t,data[0]['input_current'][:20000*5]/10,alpha=0.5)
plt.ylim([-140,110])
plt.savefig("G:/My Drive/Data For Publication/paper1/figures/Supplimentary/traces/FN_cluster1.pdf",dpi=300)  

plt.show()

# %%
data_path = "D:/ALL_SH_FOR_UPLOAD/170615_NC_19_CC.mat"
data_dict= returnVsandIs("D:/ALL_SH_FOR_UPLOAD/","170615_NC_19_CC.mat")
plt.plot(data_dict['3']['tV'][9], data_dict['3']['V'][9]*1000)
plt.ylim([-100,120])
plt.savefig("G:/My Drive/Data For Publication/paper1/figures/Supplimentary/traces/CC_cluster1.pdf",dpi=300)

# %% [markdown]
# ### Cluster 2

# %%
data_path = "D:/Niccolo_Files_FN_CC/FN_analyzed/170616_NC_20_FN_analyzed.mat"
data = loadmatInPy(data_path)
t = np.arange(0,5,1/20000)

plt.plot(t,data[0]['membrane_potential'][:20000*5],c='black')
# plt.plot(t,data[0]['input_current'][:20000*5]/10,alpha=0.5)
plt.ylim([-140,110])

plt.savefig("G:/My Drive/Data For Publication/paper1/figures/Supplimentary/traces/FN_cluster2.pdf",dpi=300)  

plt.show()

# %%
data_path = "D:/ALL_SH_FOR_UPLOAD/170616_NC_20_CC.mat"
data_dict= returnVsandIs("D:/ALL_SH_FOR_UPLOAD/","170616_NC_20_CC.mat")
plt.plot(data_dict['3']['tV'][9], data_dict['3']['V'][9]*1000)
plt.ylim([-110,120])
plt.savefig("G:/My Drive/Data For Publication/paper1/figures/Supplimentary/traces/CC_cluster2.pdf",dpi=300)

# %% [markdown]
# ### Cluster 3

# %%
data_path = "D:/Analyzed/asli_2-8-19_E1_analyzed.mat" 
data = loadmatInPy(data_path)
t = np.arange(0,5,1/20000)
plt.plot(t,data[0]['membrane_potential'][20000*5:2*20000*5],c='black')
plt.ylim([-140,110])

# plt.plot(t,data[0]['input_current'][:20000*5]/10,alpha=0.5)
plt.savefig("G:/My Drive/Data For Publication/paper1/figures/Supplimentary/traces/FN_cluster3.pdf",dpi=300)  
plt.show()

# %%
data_path = "D:/ALL_SH_FOR_UPLOAD/asli_2-8-19-E1-CCSTEP-NODRUG.mat"
data_dict= returnVsandIs("D:/ALL_SH_FOR_UPLOAD/","asli_2-8-19-E1-CCSTEP-NODRUG.mat")
plt.plot(data_dict['1']['tV'][9], data_dict['1']['V'][9]*1000)
plt.ylim([-100,120])
plt.savefig("G:/My Drive/Data For Publication/paper1/figures/Supplimentary/traces/CC_cluster3.pdf",dpi=300)

# %% [markdown]
# ### Cluster 4

# %%
data_path = "D:/Niccolo_Files_FN_CC/FN_analyzed/170620_NC_22_FN_analyzed.mat" 
data = loadmatInPy(data_path)
t = np.arange(0,5,1/20000)

plt.plot(t,data[0]['membrane_potential'][20000*5:2*20000*5],c='black')
plt.ylim([-140,110])

# plt.plot(t,data[0]['input_current'][:20000*5]/10,alpha=0.5)
plt.savefig("G:/My Drive/Data For Publication/paper1/figures/Supplimentary/traces/FN_cluster4.pdf",dpi=300)  
plt.show()

# %%
data_path = "D:/ALL_SH_FOR_UPLOAD/170620_NC_22_CC.mat"
data_dict= returnVsandIs("D:/ALL_SH_FOR_UPLOAD/","170620_NC_22_CC.mat")
plt.plot(data_dict['3']['tV'][9], data_dict['3']['V'][9]*1000)
plt.ylim([-100,120])
plt.savefig("G:/My Drive/Data For Publication/paper1/figures/Supplimentary/traces/CC_cluster4.pdf",dpi=300)

# %% [markdown]
# ### Cluster 5

# %%
data_path = "D:/Niccolo_Files_FN_CC/FN_analyzed/170628_NC_32_FN_analyzed.mat" 
data = loadmatInPy(data_path)

t = np.arange(0,5,1/20000)
plt.plot(t,data[0]['membrane_potential'][:20000*5],c='black')
# plt.plot(t,data[0]['input_current'][:20000*5]/10,alpha=0.5)
plt.ylim([-140,110])

plt.savefig("G:/My Drive/Data For Publication/paper1/figures/Supplimentary/traces/FN_cluster5.pdf",dpi=300)  

plt.show()

# %%
data_path = "D:/ALL_SH_FOR_UPLOAD/170628_NC_32_CC.mat"
data_dict= returnVsandIs("D:/ALL_SH_FOR_UPLOAD/","170628_NC_32_CC.mat")
plt.plot(data_dict['3']['tV'][9], data_dict['3']['V'][9]*1000)
plt.ylim([-100,120])
plt.savefig("G:/My Drive/Data For Publication/paper1/figures/Supplimentary/traces/CC_cluster5.pdf",dpi=300)

# %% [markdown]
# ### Cluster 6

# %%
data_path = "D:/Niccolo_Files_FN_CC/FN_analyzed/170815_NC_106_FN_analyzed.mat"  
data = loadmatInPy(data_path)
t = np.arange(0,5,1/20000)

plt.plot(t,data[0]['membrane_potential'][20000*5:2*20000*5],c='black')
# plt.plot(t,data[0]['input_current'][:20000*5]/10,alpha=0.5)
plt.ylim([-140,110])
plt.savefig("G:/My Drive/Data For Publication/paper1/figures/Supplimentary/traces/FN_cluster6.pdf",dpi=300)  

plt.show()

# %%
data_path = "D:/ALL_SH_FOR_UPLOAD/170815_NC_106_CC.mat"
data_dict= returnVsandIs("D:/ALL_SH_FOR_UPLOAD/","170815_NC_106_CC.mat")
plt.plot(data_dict['3']['tV'][9], data_dict['3']['V'][9]*1000)
plt.ylim([-100,120])
plt.savefig("G:/My Drive/Data For Publication/paper1/figures/Supplimentary/traces/CC_cluster6.pdf",dpi=300)

# %% [markdown]
# ### Cluster 7

# %%
data_path = "D:/Niccolo_Files_FN_CC/FN_analyzed/170711_NC_52_FN_analyzed.mat"  
data = loadmatInPy(data_path)
t = np.arange(0,5,1/20000)

plt.plot(t,data[0]['membrane_potential'][20000*5:2*20000*5],c='black')
# plt.plot(t,data[0]['input_current'][:20000*5]/10,alpha=0.5)
plt.ylim([-140,110])
plt.savefig("G:/My Drive/Data For Publication/paper1/figures/Supplimentary/traces/FN_cluster7.pdf",dpi=300)  

plt.show()

# %%
data_path = "D:/ALL_SH_FOR_UPLOAD/170711_NC_52_CC.mat"
data_dict= returnVsandIs("D:/ALL_SH_FOR_UPLOAD/","170711_NC_52_CC.mat")
plt.plot(data_dict['3']['tV'][9], data_dict['3']['V'][9]*1000)
plt.ylim([-100,120])
plt.savefig("G:/My Drive/Data For Publication/paper1/figures/Supplimentary/traces/CC_cluster7.pdf",dpi=300)
